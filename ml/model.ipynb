# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("sih_database.csv")

# %%
df.head()
# Out:
#      GpsProvider           BookingID Market/Regular  BookingID_Date  \
# 0  CONSENT TRACK  MVCV0000927/082021          Market      8/17/2020
# 1        VAMOSYS  VCV00014271/082021         Regular      8/27/2020
# 2  CONSENT TRACK  VCV00014382/082021         Regular      8/27/2020
# 3        VAMOSYS  VCV00014743/082021         Regular      8/28/2020
# 4        VAMOSYS  VCV00014744/082021         Regular      8/28/2020
#
#    vehicle_no                                    Origin_Location  \
# 0    KA590408               TVSLSL-PUZHAL-HUB,CHENNAI,TAMIL NADU
# 1  TN30BC5917  DAIMLER INDIA COMMERCIAL VEHICLES,KANCHIPURAM,...
# 2  TN22AR2748              LUCAS TVS LTD-PONDY,PONDY,PONDICHERRY
# 3  TN28AQ0781  DAIMLER INDIA COMMERCIAL VEHICLES,KANCHIPURAM,...
# 4   TN68F1722              LUCAS TVS LTD-PONDY,PONDY,PONDICHERRY
#
#                                 Destination_Location      Org_lat_lon  \
# 0       ASHOK LEYLAND PLANT 1- HOSUR,HOSUR,KARNATAKA  13.1550,80.1960
# ...

# %%
df.size
# Out:
# 220160

# %%
df.head()
# Out:
#      GpsProvider           BookingID Market/Regular  BookingID_Date  \
# 0  CONSENT TRACK  MVCV0000927/082021          Market      8/17/2020
# 1        VAMOSYS  VCV00014271/082021         Regular      8/27/2020
# 2  CONSENT TRACK  VCV00014382/082021         Regular      8/27/2020
# 3        VAMOSYS  VCV00014743/082021         Regular      8/28/2020
# 4        VAMOSYS  VCV00014744/082021         Regular      8/28/2020
#
#    vehicle_no                                    Origin_Location  \
# 0    KA590408               TVSLSL-PUZHAL-HUB,CHENNAI,TAMIL NADU
# 1  TN30BC5917  DAIMLER INDIA COMMERCIAL VEHICLES,KANCHIPURAM,...
# 2  TN22AR2748              LUCAS TVS LTD-PONDY,PONDY,PONDICHERRY
# 3  TN28AQ0781  DAIMLER INDIA COMMERCIAL VEHICLES,KANCHIPURAM,...
# 4   TN68F1722              LUCAS TVS LTD-PONDY,PONDY,PONDICHERRY
#
#                                 Destination_Location      Org_lat_lon  \
# 0       ASHOK LEYLAND PLANT 1- HOSUR,HOSUR,KARNATAKA  13.1550,80.1960
# ...

# %%
df.head()
# Out:
#      GpsProvider           BookingID Market/Regular  BookingID_Date  \
# 0  CONSENT TRACK  MVCV0000927/082021          Market      8/17/2020
# 1        VAMOSYS  VCV00014271/082021         Regular      8/27/2020
# 2  CONSENT TRACK  VCV00014382/082021         Regular      8/27/2020
# 3        VAMOSYS  VCV00014743/082021         Regular      8/28/2020
# 4        VAMOSYS  VCV00014744/082021         Regular      8/28/2020
#
#    vehicle_no                                    Origin_Location  \
# 0    KA590408               TVSLSL-PUZHAL-HUB,CHENNAI,TAMIL NADU
# 1  TN30BC5917  DAIMLER INDIA COMMERCIAL VEHICLES,KANCHIPURAM,...
# 2  TN22AR2748              LUCAS TVS LTD-PONDY,PONDY,PONDICHERRY
# 3  TN28AQ0781  DAIMLER INDIA COMMERCIAL VEHICLES,KANCHIPURAM,...
# 4   TN68F1722              LUCAS TVS LTD-PONDY,PONDY,PONDICHERRY
#
#                                 Destination_Location      Org_lat_lon  \
# 0       ASHOK LEYLAND PLANT 1- HOSUR,HOSUR,KARNATAKA  13.1550,80.1960
# ...

# %%
df.drop(['BookingID','vehicle_no','vehicleType','Driver_Name','Driver_MobileNo','customerID'],axis=1 ,inplace=True)

# %%
df.head()
# Out:
#      GpsProvider Market/Regular  BookingID_Date  \
# 0  CONSENT TRACK          Market      8/17/2020
# 1        VAMOSYS         Regular      8/27/2020
# 2  CONSENT TRACK         Regular      8/27/2020
# 3        VAMOSYS         Regular      8/28/2020
# 4        VAMOSYS         Regular      8/28/2020
#
#                                      Origin_Location  \
# 0               TVSLSL-PUZHAL-HUB,CHENNAI,TAMIL NADU
# 1  DAIMLER INDIA COMMERCIAL VEHICLES,KANCHIPURAM,...
# 2              LUCAS TVS LTD-PONDY,PONDY,PONDICHERRY
# 3  DAIMLER INDIA COMMERCIAL VEHICLES,KANCHIPURAM,...
# 4              LUCAS TVS LTD-PONDY,PONDY,PONDICHERRY
#
#                                 Destination_Location      Org_lat_lon  \
# 0       ASHOK LEYLAND PLANT 1- HOSUR,HOSUR,KARNATAKA  13.1550,80.1960
# 1  DAIMLER INDIA COMMERCIAL VEHICLES,KANCHIPURAM,...  12.8390,79.9540
# 2              LUCAS TVS LTD-PONDY,PONDY,PONDICHERRY  11.8710,79.7390
# ...

# %%
df.drop('trip_end_date',axis=1,inplace=True)

# %%
df.size
# Out:
# 172000

# %%
df.drop('Minimum_kms_to_be_covered_in_a_day',axis=1,inplace=True)

# %%
df.head()
# Out:
#      GpsProvider Market/Regular  BookingID_Date  \
# 0  CONSENT TRACK          Market      8/17/2020
# 1        VAMOSYS         Regular      8/27/2020
# 2  CONSENT TRACK         Regular      8/27/2020
# 3        VAMOSYS         Regular      8/28/2020
# 4        VAMOSYS         Regular      8/28/2020
#
#                                      Origin_Location  \
# 0               TVSLSL-PUZHAL-HUB,CHENNAI,TAMIL NADU
# 1  DAIMLER INDIA COMMERCIAL VEHICLES,KANCHIPURAM,...
# 2              LUCAS TVS LTD-PONDY,PONDY,PONDICHERRY
# 3  DAIMLER INDIA COMMERCIAL VEHICLES,KANCHIPURAM,...
# 4              LUCAS TVS LTD-PONDY,PONDY,PONDICHERRY
#
#                                 Destination_Location      Org_lat_lon  \
# 0       ASHOK LEYLAND PLANT 1- HOSUR,HOSUR,KARNATAKA  13.1550,80.1960
# 1  DAIMLER INDIA COMMERCIAL VEHICLES,KANCHIPURAM,...  12.8390,79.9540
# 2              LUCAS TVS LTD-PONDY,PONDY,PONDICHERRY  11.8710,79.7390
# ...

# %%
df.isnull().sum()
# Out:
# GpsProvider                       953
# Market/Regular                      0
# BookingID_Date                      0
# Origin_Location                     0
# Destination_Location                0
# Org_lat_lon                         0
# Des_lat_lon                         0
# Data_Ping_time                    953
# Planned_ETA                         0
# Current_Location                  964
# DestinationLocation                 0
# actual_eta                         37
# Curr_lat                          953
# Curr_lon                          953
# ontime                           4332
# delay                            2538
# OriginLocation_Code                 3
# DestinationLocation_Code           27
# trip_start_date                     0
# TRANSPORTATION_DISTANCE_IN_KM     712
# customerNameCode                    0
# supplierID                          0
# supplierNameCode                    0
# Material Shipped                    0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# GpsProvider                      0
# Market/Regular                   0
# BookingID_Date                   0
# Origin_Location                  0
# Destination_Location             0
# Org_lat_lon                      0
# Des_lat_lon                      0
# Data_Ping_time                   0
# Planned_ETA                      0
# Current_Location                 0
# DestinationLocation              0
# actual_eta                       0
# Curr_lat                         0
# Curr_lon                         0
# ontime                           0
# delay                            0
# OriginLocation_Code              0
# DestinationLocation_Code         0
# trip_start_date                  0
# TRANSPORTATION_DISTANCE_IN_KM    0
# customerNameCode                 0
# supplierID                       0
# supplierNameCode                 0
# Material Shipped                 0
# dtype: int64

# %%
df.size
# Out:
# 408

# %%
df.head()
# Out:
#      GpsProvider Market/Regular  BookingID_Date  \
# 5820        WDSL         Regular      6/15/2019
# 5821        WDSL         Regular      6/15/2019
# 5822        WDSL         Regular      6/15/2019
# 5823        WDSL         Regular      6/14/2019
# 5824        WDSL         Regular      6/14/2019
#
#                              Origin_Location  \
# 5820           Kuldanga, Howrah, West Bengal
# 5821             Sonai, Kolkata, West Bengal
# 5822             Sonai, Kolkata, West Bengal
# 5823  Tunglam, Visakhapatnam, Andhra Pradesh
# 5824                Kollur, Medak, Telangana
#
#                      Destination_Location  \
# 5820         Kadma, Hazaribagh, Jharkhand
# 5821        Sarasdangal, Dumka, Jharkhand
# 5822          Satpahari, Dumka, Jharkhand
# 5823    Muktyala, Krishna, Andhra Pradesh
# 5824  R G I Airport, Hyderabad, Telangana
#
#                                 Org_lat_lon  \
# 5820  16.560192249175344,80.792293091599547
# ...
